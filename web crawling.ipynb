# %%
# importing modules
import urllib.request 
from bs4 import BeautifulSoup
  
# providing url
url = "https://www.booking.com/index.html?aid=1743217"
  
# opening the url for reading
html = urllib.request.urlopen(url)
# parsing the html file
htmlParse = BeautifulSoup(html, 'html.parser')
  
# getting all the paragraphs
for para in htmlParse.find_all("p"):
    x.append(para.get_text()
    #print(para.get_text())
    print(x)
# Out:
# Get the advice you need. Check the latest COVID-19 restrictions before you travel.
#
# Learn more
#
#
#
# Plan your dream trip with a Getaway Deal
#
#
# 62 properties
#
#
# 56 properties
#
#
# 78 properties
#
#
# 94 properties
#
#
# 60 properties
#
# Rome
# Starting from $275
# Lisbon
# Starting from $222
# Nice
# Starting from $268
# Budapest
# Starting from $107
# Prague
# Starting from $147
#
# Prices drop the second you sign up!
#
#
#
# Error:
# Please enter a valid email address.
#
#
#
# Error:
# Oops! An error has occurred.
#
#
#
# Thanks! We've sent you an email so you can confirm your subscription
#
# Marvel at the spectacle of mother nature at these fascinating locations.
# The best places to enjoy spring around the world.
# Celebrate Fashion Week in style at one of these trendsetting spots.
# Vegan-friendly eateries abound in these travel destinations…
# Featuring Welsh seaside towns and vibrant night markets in Taiwan’s second largest city.
# 853,158 hotels
# 795,318 apartments
# 17,709 resorts
# 418,417 villas
# 33,266 cabins
# 140,167 cottages
# 11,263 Glamping Sites
# 32,942 serviced apartments
# 418,417 vacation homes
# 100,460 guest houses
# 16,323 hostels
# 13,066 motels
# 194,976 B&Bs
# 2,054 ryokans
# 1,165 riads
# 5,534 resort villages
# 132,304 homestays
# 8,436 campgrounds
# 11,800 country houses
# 10,536 farm stays
# 1,321 boats
# 3,440 luxury tents
# 698,278 Self-catering Properties
# 443 tiny houses
#
#
# Error:
# Please enter a valid email address.
#
#
#
# Error:
# Oops! An error has occurred.
#
#
#
# Thanks! We've sent you an email so you can confirm your subscription
#
#
#
# List your property
#
#
# Booking.com is part of Booking Holdings Inc., the world leader in online travel and related services.
#
# We have more than 70 million property reviews, all from real, verified guests.
# 1
#
# The only way to leave a review is to first make a booking. That's how we know our reviews come from real guests who have stayed at the property.
#
# 2
#
# When guests stay at the property, they check out how quiet the room is, how friendly the staff is, and more.
#
# 3
#
# After their trip, guests tell us about their stay. We check for naughty words and verify the authenticity of all guest reviews before adding them to our site.
# If you booked through us and want to leave a review, please sign in first.
# Check-in date
# Check-out date

# %%
# importing modules
import urllib.request 
from bs4 import BeautifulSoup
import pandas as pd

x=[]
# providing url
url = "https://www.booking.com/index.html?aid=1743217"
  
# opening the url for reading
html = urllib.request.urlopen(url)
# parsing the html file
htmlParse = BeautifulSoup(html, 'html.parser')
  
# getting all the paragraphs
for para in htmlParse.find_all("p"):
    x.append(para.get_text())

text=""
for i in x:
    text+=" "+str(i)
text=text.strip()
    
#print(text)
df=pd.DataFrame({'text':[text]})
df

def preprocess_text(sen):
    sentence = remove_tags(sen)
    sentence = re.sub('[^a-zA-Z]', ' ', sentence)
    sentence = re.sub(r"\s+[a-zA-Z]\s+", ' ', sentence)
    sentence = re.sub(r'\s+', ' ', sentence)
    return sentence
	
TAG_RE = re.compile(r'<[^>]+>')
def remove_tags(text):
    return TAG_RE.sub('', text)
	
X = []
sentences = list(df['text'])
for sen in sentences:
    X.append(preprocess_text(sen))
print(X)
df=pd.DataFrame({'text':[X[0]]})
df
# Out:
# ['Get rewarded for your travels unlock instant savings of or more with free Booking com account Get the advice you need Check the latest COVID restrictions before you travel Learn more Plan your dream trip with Getaway Deal Lisbon Starting from Rome Starting from Barcelona Starting from Split Starting from London Starting from Prices drop the second you sign up Error Please enter valid email address Error Oops An error has occurred Thanks We ve sent you an email so you can confirm your subscription Marvel at the spectacle of mother nature at these fascinating locations The best places to enjoy spring around the world Celebrate Fashion Week in style at one of these trendsetting spots Vegan friendly eateries abound in these travel destinations Featuring Welsh seaside towns and vibrant night markets in Taiwan second largest city properties properties properties properties properties hotels apartments resorts villas cabins cottages Glamping Sites serviced apartments vacation homes guest houses hostels motels Bs ryokans riads resort villages homestays campgrounds country houses farm stays boats luxury tents Self catering Properties tiny houses Error Please enter valid email address Error Oops An error has occurred Thanks We ve sent you an email so you can confirm your subscription List your property Booking com is part of Booking Holdings Inc the world leader in online travel and related services We have more than million property reviews all from real verified guests The only way to leave review is to first make booking That how we know our reviews come from real guests who have stayed at the property When guests stay at the property they check out how quiet the room is how friendly the staff is and more After their trip guests tell us about their stay We check for naughty words and verify the authenticity of all guest reviews before adding them to our site If you booked through us and want to leave review please sign in first Check in date Check out date']
#                                                 text
# 0  Get rewarded for your travels unlock instant s...

# %%
import pandas as pd
import re
df = pd.DataFrame(output, columns =['text']) 

def preprocess_text(sen):
    sentence = remove_tags(sen)
    sentence = re.sub('[^a-zA-Z]', ' ', sentence)
    sentence = re.sub(r"\s+[a-zA-Z]\s+", ' ', sentence)
    sentence = re.sub(r'\s+', ' ', sentence)
    return sentence
	
TAG_RE = re.compile(r'<[^>]+>')
def remove_tags(text):
    return TAG_RE.sub('', text)
	
X = []
sentences = list(df['text'])
for sen in sentences:
    X.append(preprocess_text(sen))
print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f58e62fdf6df> in <module>()
#       1 import pandas as pd
#       2 import re
# ----> 3 df = pd.DataFrame(output, columns =['text'])
#       4
#       5 def preprocess_text(sen):
#
# NameError: name 'output' is not defined

# %%
import requests
from bs4 import BeautifulSoup

"""f=open('url.txt','r')
url = f.read()
f.close()"""
url="https://www.booking.com/index.html?aid=1743217"

res = requests.get(url)
html_page = res.content
soup = BeautifulSoup(html_page, 'html.parser')
text = soup.find_all(text=True)

output = ''
blacklist = [
    '[document]',
    'noscript',
    'header',
    'html',
    'meta',
    'head', 
    'input',
    'script',
]

for t in text:
    if t.parent.name not in blacklist:
        output += '{} '.format(t)

print(output)
output = [output]
# Out:
#
#
#
#
#
#
#
#   #basiclayout, .basiclayout { margin: 0; } #special_actions { margin: 3px 15px 3px 0; } .ticker_space { margin-top: 3px !important; } #logo_no_globe_new_logo { top: 14px; } .b_msie_6 #top, .b_msie_6 body.header_reshuffle #top {height:61px !important;} .b_msie_6 #special_actions { margin: 3px 15px 3px 0; overflow:visible; } body.header_reshuffle #top { min-height: 50px !important; height: auto !important; } .nobg { background: #fff url("https://cf.bstatic.com/static/img/nobg_all_blue_iq/b700d9e3067c1186a3364012df4fe1c48ae6da44.png") repeat-x; background-position: 0 -50px; }
#
#
#
#
#
#
#
#
#
#
# Booking.com | Official site | The best hotels, flights, car rentals & accommodations
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [if IE]> <script nonce="sJ0A7lH3eXUK6Yd"> document.createElement('time'); </script> <![endif]
#
#
#
#
#
#  Skip to main content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# USD
#
#
# Choose your currency.
# Your current currency is U.S. Dollar
#
#
#
#
#
#
#
#
#
#
#
# Choose your language.
# Your current language is English (US)
#
#
#
#
#
#
# Select your language
#
#
#
#
#
#
#
# Suggested for you
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# English (UK)
#
#
#
#
#
#
#
#
#
#
#
#
#
# Español
#
#
#
#
#
#
#
#
#
#
#
#
#
# 简体中文
#
#
#
#
#
#
#
#
#
#
#
#
#
# Русский
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 日本語
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# All languages
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# English (UK)
#
#
#
#
#
#
#
#
#
#
#
#
#
# English (US)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Deutsch
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nederlands
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Français
#
#
#
#
#
#
#
#
#
#
#
#
#
# Español
#
#
#
#
#
#
#
#
#
#
#
#
#
# Español (AR)
#
#
#
#
#
#
#
#
#
#
#
#
#
# Español (MX)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Català
#
#
#
#
#
#
#
#
#
#
#
#
#
# Italiano
#
#
#
#
#
#
#
#
#
#
#
#
#
# Português (PT)
#
#
#
#
#
#
#
#
#
#
#
#
#
# Português (BR)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Norsk
#
#
#
#
#
#
#
#
#
#
#
#
#
# Suomi
#
#
#
#
#
#
#
#
#
#
#
#
#
# Svenska
#
#
#
#
#
#
#
#
#
#
#
#
#
# Dansk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Čeština
#
#
#
#
#
#
#
#
#
#
#
#
#
# Magyar
#
#
#
#
#
#
#
#
#
#
#
#
#
# Română
#
#
#
#
#
#
#
#
#
#
#
#
#
# 日本語
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 简体中文
#
#
#
#
#
#
#
#
#
#
#
#
#
# 繁體中文
#
#
#
#
#
#
#
#
#
#
#
#
#
# Polski
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ελληνικά
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Русский
#
#
#
#
#
#
#
#
#
#
#
#
#
# Türkçe
#
#
#
#
#
#
#
#
#
#
#
#
#
# Български
#
#
#
#
#
#
#
#
#
#
#
#
#
# العربية
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 한국어
#
#
#
#
#
#
#
#
#
#
#
#
#
# עברית
#
#
#
#
#
#
#
#
#
#
#
#
#
# Latviski
#
#
#
#
#
#
#
#
#
#
#
#
#
# Українська
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Bahasa Indonesia
#
#
#
#
#
#
#
#
#
#
#
#
#
# Bahasa Malaysia
#
#
#
#
#
#
#
#
#
#
#
#
#
# ภาษาไทย
#
#
#
#
#
#
#
#
#
#
#
#
#
# Eesti
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hrvatski
#
#
#
#
#
#
#
#
#
#
#
#
#
# Lietuvių
#
#
#
#
#
#
#
#
#
#
#
#
#
# Slovenčina
#
#
#
#
#
#
#
#
#
#
#
#
#
# Srpski
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Slovenščina
#
#
#
#
#
#
#
#
#
#
#
#
#
# Tiếng Việt
#
#
#
#
#
#
#
#
#
#
#
#
#
# Filipino
#
#
#
#
#
#
#
#
#
#
#
#
#
# Íslenska
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Get help with your reservation
#
#
#
#
#
#
#
#
# List your property
#
#
#
#
#
#
# Register
#
#
#
#
#
#
#
# Sign in
#
#
#
#
#
#
#
#
#
#
#
#
# Stays
#
#
#
#
#
#
#
#
#
# Flights
#
#
#
#
#
#
#
#
#
# Flight + Hotel
#
#
#
#
#
#
#
#
#
# Car rentals
#
#
#
#
#
#
#
#
#
# Attractions
#
#
#
#
#
#
#
#
#
# Airport taxis
#
#
#
#
#
#
#
#  A lifetime of discounts? It's Genius. Get rewarded for your travels – unlock instant savings of 10% or more with a free Booking.com account Sign in / Register
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Type your destination
#
#
#
#
#
#
#  Error:
# Enter a destination to start searching.
#
#
#
#  Try searching for...
#
#
# Les Anses-dʼArlets
#
#
# Pyla
#
#
# Pointe-Noire
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# +
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Check-in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# +
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Check-out
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Rooms and occupancy
#
#
# 2 adults
#
#
#  ·
#
# 0 children
#
#
#
#  ·
#
# 1 room
#
#
#
#
#
#
#
#
#
#
#
#  Adults
#
#
#
#
#  −
#
#  2
#
#  +
#
#  2 Adults
#
#
#
#
#
#
#  Children
#  Ages 0 – 17
#
#
#
#
#  −
#
#  0
#
#  +
#
#  0 Children
#
#
#
#
#
#
#
#  Rooms
#
#
#
#
#  −
#
#  1
#
#  +
#
#  1 Rooms
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
# I'm looking for an entire home or apartment
#
#
#
#
# I'm traveling for work
#
#
#
#  Your results will be shown on the map.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Get the advice you need. Check the latest COVID-19 restrictions before you travel.
#
# Learn more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Save 15% or more
#
#
# Plan your dream trip with a Getaway Deal
#
#
#  Explore deals
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Subscribe to see Secret Deals
#
#
# Prices drop the second you sign up!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Sign me up!
#
#
#
#
#  Error:
# Please enter a valid email address.
#
#
#
#  Error:
# Oops! An error has occurred.
#
#
#
# Thanks! We've sent you an email so you can confirm your subscription
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Explore United States of America
#  These popular destinations have a lot to offer
#
#
#
#
#
#
#
#
#
#
#  Las Vegas
#  565 properties
#
#
#
#
#
#
#
#
#
#
#
#  Myrtle Beach
#  2,643 properties
#
#
#
#
#
#
#
#
#
#
#
#  Orlando
#  3,684 properties
#
#
#
#
#
#
#
#
#
#
#
#  Miami Beach
#  718 properties
#
#
#
#
#
#
#
#
#
#
#
#  New York
#  1,381 properties
#
#
#
#
#
#
#
#
#
#
#
#  Panama City Beach
#  2,077 properties
#
#
#
#
#
#
#
#
#
#
#
#  Destin
#  2,341 properties
#
#
#
#
#
#
#
#
#
#
#
#  Los Angeles
#  1,715 properties
#
#
#
#
#
#
#
#
#
#
#
#  Atlanta
#  920 properties
#
#
#
#
#
#
#
#
#
#
#
#  Pigeon Forge
#  958 properties
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Connect with other travelers
#
#
#
#
#
#
#
#
#
#
#
# India
#
#
# Travel community
#
#
# 155,073 travelers
#
#
#
#
#
#
#
#
#
#
#
# Travel Talk
#
#
# General discussion
#
#
# 559,436 travelers
#
#
#
#
#
#
#
#
#
#
#
# More communities
#
#
# View all
#
#
# 9,894,940 travelers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Get inspiration for your next trip
#
#
#
#
#
#
#  The best of the earth's natural beauty
#  Marvel at the spectacle of mother nature at these fascinating locations.
#
#
#
#
#
#
#  The most beautiful destinations for spring
#  The best places to enjoy spring around the world.
#
#
#
#
#
#
#  New York City’s 6 most fashionable hotels
#  Celebrate Fashion Week in style at one of these trendsetting spots.
#
#
#
#
#
#
#  The top 5 cities for vegan travelers
#  Vegan-friendly eateries abound in these travel destinations…
#
#
#
#
#
#
#  The top travel destinations for 2022
#  Featuring Welsh seaside towns and vibrant night markets in Taiwan’s second largest city.
#
#
#
#
#
#
#
# Browse by property type
#
#
#
#
#
#
#
#
#
#
#
# Hotels
#
#
#  853,159 hotels
#
#
#
#
#
#
#
#
#
#
#
# Apartments
#
#
#  795,318 apartments
#
#
#
#
#
#
#
#
#
#
#
# Resorts
#
#
#  17,709 resorts
#
#
#
#
#
#
#
#
#
#
#
# Villas
#
#
#  418,417 villas
#
#
#
#
#
#
#
#
#
#
#
# Cabins
#
#
#  33,266 cabins
#
#
#
#
#
#
#
#
#
#
#
# Cottages
#
#
#  140,167 cottages
#
#
#
#
#
#
#
#
#
#
#
# Glamping
#
#
#  11,263 Glamping Sites
#
#
#
#
#
#
#
#
#
#
#
# Serviced Apartments
#
#
#  32,942 serviced apartments
#
#
#
#
#
#
#
#
#
#
#
# Vacation Homes
#
#
#  418,417 vacation homes
#
#
#
#
#
#
#
#
#
#
#
# Guest houses
#
#
#  100,460 guest houses
#
#
#
#
#
#
#
#
#
#
#
# Hostels
#
#
#  16,323 hostels
#
#
#
#
#
#
#
#
#
#
#
# Motels
#
#
#  13,066 motels
#
#
#
#
#
#
#
#
#
#
#
# B&Bs
#
#
#  194,976 B&Bs
#
#
#
#
#
#
#
#
#
#
#
# Ryokans
#
#
#  2,054 ryokans
#
#
#
#
#
#
#
#
#
#
#
# Riads
#
#
#  1,165 riads
#
#
#
#
#
#
#
#
#
#
#
# Resort Villages
#
#
#  5,534 resort villages
#
#
#
#
#
#
#
#
#
#
#
# Homestays
#
#
#  132,304 homestays
#
#
#
#
#
#
#
#
#
#
#
# Campgrounds
#
#
#  8,436 campgrounds
#
#
#
#
#
#
#
#
#
#
#
# Country Houses
#
#
#  11,800 country houses
#
#
#
#
#
#
#
#
#
#
#
# Farm Stays
#
#
#  10,536 farm stays
#
#
#
#
#
#
#
#
#
#
#
# Boats
#
#
#  1,321 boats
#
#
#
#
#
#
#
#
#
#
#
# Luxury Tents
#
#
#  3,440 luxury tents
#
#
#
#
#
#
#
#
#
#
#
# Self-catering Accommodations
#
#
#  698,278 Self-catering Properties
#
#
#
#
#
#
#
#
#
#
#
# Tiny houses
#
#
#  443 tiny houses
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Recommended destinations
#
#
#
#
#
#
#
#
#
#
# Les Anses-dʼArlets
#
#
#
# 62 properties
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Pyla
#
#
#
# 56 properties
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Pointe-Noire
#
#
#
# 78 properties
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# La Trinité
#
#
#
# 94 properties
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Dittishausen
#
#
#
# 60 properties
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Get instant discounts
#
# Just sign into your Booking.com account and look for the blue Genius logo to save
#
#
#
#
# Sign in
#
#
#
#
# Register
#
#
#
#
#
#
#
#
# More than just hotels... Bookers discover pure comfort with homes, apartments, and more
#
#
#
#
#
#
#
#  The Apartments by The Sloane Club
#  London
#  Starting from $415
#
#     9.3       Awesome
#      121 reviews
#
#
#
#
#
#
#
#
#  Appartamento Benincampi
#  Rome
#  Starting from $313
#
#     9.7       Exceptional
#      71 reviews
#
#
#
#
#
#
#
#
#  Chiado Mercy Apartments | Lisbon Best Apartments
#  Lisbon
#  Starting from $222
#
#     9.6       Exceptional
#      625 reviews
#
#
#
#
#
#
#
#
#  VIP Residence Budapest
#  Budapest
#  Starting from $393
#
#     9.6       Exceptional
#      30 reviews
#
#
#
#
#
#
#
#
#  Pick A Flat's in Champs Elysees - rue Percier
#  Paris
#  Starting from $456
#
#     8.8       Excellent
#      6 reviews
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     /basiclayout
#
#
#
#     lp-general_content_wrapper
#
#
#
#
#  Destinations Bookers love
#
#
#
#
#  Regions
#
#
#
#
#  Cities
#
#
#
#
#  Places of interest
#
#
#
#
#
#
#
# Jersey
#
#  89 properties
#
#
#
# Zanzibar
#
#  837 properties
#
#
#
# Bihar
#
#  761 properties
#
#
#
# Ras Al Khaimah
#
#  114 properties
#
#
#
# Uttar Pradesh
#
#  4,372 properties
#
#
#
# Tenerife
#
#  9,608 properties
#
#
#
# Hawaii
#
#  5,517 properties
#
#
#
# Mykonos
#
#  1,453 properties
#
#
#
# Guernsey
#
#  61 properties
#
#
#
# Phuket Province
#
#  5,495 properties
#
#
#
# Ibiza
#
#  1,642 properties
#
#
#
# Bora Bora
#
#  59 properties
#
#
#
# Bali
#
#  12,683 properties
#
#
#
# Lake District
#
#  2,409 properties
#
#
#
# Santorini
#
#  1,765 properties
#
#
#
# Isle of Wight
#
#  934 properties
#
#
#
# Cornwall
#
#  5,278 properties
#
#
#
# England
#
#  74,041 properties
#
#
#
# Texel
#
#  412 properties
#
#
#
#
#
#
#
#
#
#  Mácher,
# Spain
#
#
#  40 vacation rentals ,  25 cottages ,  24 vacation homes ,  24 villas ,  21 cottages
#
#
#
#
#  Rankwitz,
# Germany
#
#
#  23 vacation rentals ,  17 villas ,  17 cottages ,  17 vacation homes ,  6 apartments
#
#
#
#
#  Pruchten,
# Germany
#
#
#  24 vacation rentals ,  17 apartments ,  7 villas ,  7 cottages ,  7 vacation homes
#
#
#
#
#
#
#  Sirkka,
# Finland
#
#
#  109 vacation rentals ,  105 cottages ,  102 villas ,  102 vacation homes ,  5 cottages
#
#
#
#
#  Vester Sømarken,
# Denmark
#
#
#  36 cottages ,  36 vacation homes ,  36 villas ,  36 vacation rentals
#
#
#
#
#  Torre de Benagalbón,
# Spain
#
#
#  36 vacation rentals ,  23 apartments ,  13 vacation homes ,  13 cottages ,  13 villas
#
#
#
#
#
#
#  Bangkok
#
#  4040 hotels
#
#
#
#
#  York
#
#  827 hotels
#
#
#
#
#  Newcastle upon Tyne
#
#  387 hotels
#
#
#
#
#  Manchester
#
#  1087 hotels
#
#
#
#
#
#
#  London
#
#  14505 hotels
#
#
#
#
#  Liverpool
#
#  1081 hotels
#
#
#
#
#  Leeds
#
#  382 hotels
#
#
#
#
#  Glasgow
#
#  915 hotels
#
#
#
#
#
#
#  Edinburgh
#
#  3343 hotels
#
#
#
#
#  Carbis Bay
#
#  68 hotels
#
#
#
#
#  Brighton & Hove
#
#  855 hotels
#
#
#
#
#  Bournemouth
#
#  403 hotels
#
#
#
#
#
#
#  Blackpool
#
#  896 hotels
#
#
#
#
#  Birmingham
#
#  1008 hotels
#
#
#
#
#  Stockholm
#
#  435 hotels
#
#
#
#
#  Manila
#
#  4801 hotels
#
#
#
#
#
#
#  Kuala Lumpur
#
#  4224 hotels
#
#
#
#
#  Amsterdam
#
#  1892 hotels
#
#
#
#
#  New Delhi
#
#  2911 hotels
#
#
#
#
#  Mumbai
#
#  1652 hotels
#
#
#
#
#
#
#  Berlin
#
#  1748 hotels
#
#
#
#
#  Sydney
#
#  3621 hotels
#
#
#
#
#  Perth
#
#  887 hotels
#
#
#
#
#  Melbourne
#
#  2830 hotels
#
#
#
#
#
#
#  Gold Coast
#
#  1574 hotels
#
#
#
#
#  Canberra
#
#  184 hotels
#
#
#
#
#  Brisbane
#
#  894 hotels
#
#
#
#
#  Adelaide
#
#  416 hotels
#
#
#
#
#
#
#  Wellington
#
#  164 hotels
#
#
#
#
#  Auckland
#
#  1688 hotels
#
#
#
#
#  Killarney
#
#  263 hotels
#
#
#
#
#  Galway
#
#  404 hotels
#
#
#
#
#
#
#  Dublin
#
#  1220 hotels
#
#
#
#
#  Cork
#
#  138 hotels
#
#
#
#
#  Paris
#
#  7554 hotels
#
#
#
#
#  Hong Kong
#
#  812 hotels
#
#
#
#
#
#
#  Doha
#
#  161 hotels
#
#
#
#
#  Ras al Khaimah
#
#  114 hotels
#
#
#
#
#  Dubai
#
#  4286 hotels
#
#
#
#
#  Fujairah
#
#  22 hotels
#
#
#
#
#
#
#  Ajman
#
#  81 hotels
#
#
#
#
#  Abu Dhabi
#
#  169 hotels
#
#
#
#
#  Istanbul
#
#  4208 hotels
#
#
#
#
#  Seoul
#
#  2304 hotels
#
#
#
#
#
#
#  Vancouver
#
#  627 hotels
#
#
#
#
#  Toronto
#
#  2029 hotels
#
#
#
#
#  Ottawa
#
#  240 hotels
#
#
#
#
#  Niagara Falls
#
#  253 hotels
#
#
#
#
#
#
#  Montreal
#
#  1118 hotels
#
#
#
#
#  Kelowna
#
#  214 hotels
#
#
#
#
#  Jasper
#
#  55 hotels
#
#
#
#
#  Edmonton
#
#  274 hotels
#
#
#
#
#
#
#  Canmore
#
#  149 hotels
#
#
#
#
#  Banff
#
#  50 hotels
#
#
#
#
#  Barcelona
#
#  3302 hotels
#
#
#
#
#  Tokyo
#
#  5653 hotels
#
#
#
#
#
#
#  Singapore
#
#  806 hotels
#
#
#
#
#  Whistler
#
#  332 hotels
#
#
#
#
#  Rotorua
#
#  279 hotels
#
#
#
#
#  Queenstown
#
#  823 hotels
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Heathrow Terminal 2
#
#
#
#
# Niagara Falls State Park
#
#  75 properties
#
#
#
# Comal River Tubing
#
#  327 properties
#
#
#
# River Walk
#
#  670 properties
#
#
#
# Disneyland Paris
#
#  7,554 properties
#
#
#
# Times Square
#
#  1,383 properties
#
#
#
# Ocean City Boardwalk
#
#  766 properties
#
#
#
# Universal Studios Orlando
#
#  3,685 properties
#
#
#
# The Shard
#
#  14,504 properties
#
#
#
# Eiffel Tower
#
#  7,554 properties
#
#
#
# Al Maha Wildlife Reserve
#
#  1 property
#
#
#
# Disneyland
#
#  247 properties
#
#
#
# Portmeirion
#
#  9 properties
#
#
#
# Kalahari Waterpark
#
#  43 properties
#
#
#
# State Park
#
#  21 properties
#
#
#
# Wembley Stadium
#
#  14,504 properties
#
#
#
# Burj Al Arab Tower
#
#  4,286 properties
#
#
#
# O2 Arena
#
#  14,504 properties
#
#
#
# Guadalupe River Tubing
#
#  327 properties
#
#
#
# Heathrow Terminal 5
#
#  62 properties
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Save time, save money!
#
#
# Sign up and we'll send the best deals to you
#
#
#
#
# Enter your email address and we'll send you our best deals
#
#
#
#
# Subscribe
#
#
#
#
# Send me a link to get the FREE Booking.com app!
#
#
#
#
#  Error:
# Please enter a valid email address.
#
#
#
#  Error:
# Oops! An error has occurred.
#
#
#
# Thanks! We've sent you an email so you can confirm your subscription
#
#
#
#
#  .grecaptcha-badge { display: none; bottom: 90px !important; }
#
#
#
#
#
#
#
#
#
#
#
#
# List your property
#
#
#
#
#
#
#
#
#
#  Mobile version
#
#
#
# Your account
#
#
#
#
# Make changes online to your booking
#
#
#
#
# Customer Service Help
#
#
#
#
#
# Become an affiliate
#
#
#
#
#  Booking.com for Business
#
#
#
#
#
#
#
#
#
#
#
#
# Countries
#
#
#
#
# Regions
#
#
#
#
# Cities
#
#
#
#
# Districts
#
#
#
#
# Airports
#
#
#
#
# Hotels
#
#
#
#
# Places of interest
#
#
#
#
#
#
#
#
# Homes
#
#
#
#
# Apartments
#
#
#
#
# Resorts
#
#
#
#
# Villas
#
#
#
#
# Hostels
#
#
#
#
# B&Bs
#
#
#
#
# Guest houses
#
#
#
#
#
#
#
#
# Unique places to stay
#
#
#
#
# All destinations
#
#
#
#
# Discover
#
#
#
#
# Reviews
#
#
#
#
# Unpacked: Travel articles
#
#
#
#
# Travel communities
#
#
#
#
# Seasonal and holiday deals
#
#
#
#
#
#
#
#
# Car rental
#
#
#
#
# Flight finder
#
#
#
#
# Restaurant reservations
#
#
#
#
# Booking.com for Travel Agents
#
#
#
#
#
#
#
#
# Coronavirus (COVID-19) FAQs
#
#
#
#  About Booking.com
#
#
#
# Customer Service Help
#
#
#
#
# Partner help
#
#
#
#
# Careers
#
#
#
#
# Sustainability
#
#
#
#
# Press center
#
#
#
#
# Safety Resource Center
#
#
#
#
# Investor relations
#
#
#
#
# Terms & conditions
#
#
#
#
# Dispute resolution
#
#
#
#
# How We Work
#
#
#
#
# Privacy & cookie statement
#
#
#
#
# Corporate contact
#
#
#
#
#
#
#
#
#
# Extranet login
#
#
#
#
#
# Copyright © 1996–2022
# Booking.com™. All rights reserved.
#
#
#
#
#
#
#
#
#  Booking.com is part of Booking Holdings Inc., the world leader in online travel and related services.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Start of dialog content
#
#  Verified reviews from real guests.
#  We have more than 70 million property reviews, all from  real, verified guests .
#
#
#
#  How does it work?
#
#
#
#
#  1
#
#
#
#  It starts with a booking
#  It starts with a booking
#  The only way to leave a review is to first make a booking. That's how we know our reviews come from real guests who have stayed at the property.
#
#
#
#
#
#
#
#  2
#
#
#
#  Followed by a trip
#  Followed by a trip
#  When guests stay at the property, they check out how quiet the room is, how friendly the staff is, and more.
#
#
#
#
#
#
#
#  3
#
#
#
#  And finally, a review
#  And finally, a review
#  After their trip, guests tell us about their stay. We check for naughty words and verify the authenticity of all guest reviews before adding them to our site.
#
#
#
#
#  If you booked through us and want to leave a review, please sign in first.
#
#  Sign in and leave a review
#
#  End of dialog content
#
#  Check-in date
#  Check-out date
#
#
#  «
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  »
#
#
#
#
#  Su
#  Mo
#  Tu
#  We
#  Th
#  Fr
#  Sa
#
#
#
#
#
#
#
#
#
#  Close calendar
#
#
#
#
#
#
#
#
#
#
# Sign in to continue
#
#
#
# Sign in to your account
#
#
#
#
#  or use one of these options
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Don't have an account yet?  Create your account
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  1505570,1518280,1517740,1499750,1507290,1518210,1517750,1518200,1509770,1517730,1505850,1517320,1517760,1464770,1520630,1505100,1499880,1505510,1518980,1515850
